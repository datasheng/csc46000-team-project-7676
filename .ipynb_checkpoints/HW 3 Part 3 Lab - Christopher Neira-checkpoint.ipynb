# %% [markdown]
# Requesting and Testting beautiful soup on the webpage

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

#Requesting from CCNY Calendar 
CityCalendar = requests.get("https://www.ccny.cuny.edu/registrar/fall")
CitySoup = BeautifulSoup(CityCalendar.text)
print(CitySoup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="40.8200471,-73.9492724" name="icbm"/>
#   <meta content="The City College of New York" name="geo.placename"/>
#   <meta content="40.8200471,-73.9492724" name="geo.position"/>
#   <meta content="US-NY" name="geo.region"/>
#   <link href="https://www.ccny.cuny.edu/registrar/fall" rel="canonical"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="Drupal 9" name="generator"/>
#   <meta content="The City College of New York" property="og:site_name"/>
#   <meta content="text" property="og:type"/>
# ...

# %%
CitySouped = requests.get("https://www.ccny.cuny.edu/registrar/fall")
print(CitySouped.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#   <head>
#     <meta charset="utf-8" />
# <meta name="icbm" content="40.8200471,-73.9492724" />
# <meta name="geo.placename" content="The City College of New York" />
# <meta name="geo.position" content="40.8200471,-73.9492724" />
# <meta name="geo.region" content="US-NY" />
# <link rel="canonical" href="https://www.ccny.cuny.edu/registrar/fall" />
# <meta name="robots" content="index, follow" />
# <meta name="generator" content="Drupal 9" />
# <meta property="og:site_name" content="The City College of New York" />
# <meta property="og:type" content="text" />
# ...
