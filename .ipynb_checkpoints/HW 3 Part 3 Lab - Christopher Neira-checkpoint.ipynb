# %% [markdown]
# Testing imported libraries work correctly

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
#Testing Requests
print(requests.get("https://www.google.com").status_code)

#Testing Pandas Dataframe
Listoide = pd.DataFrame({
    "Color": ["Red"],
    "Animal": ["Panda"],
    "Alive": ["23"]
})
print(Listoide)

#Testing datetime
print(datetime.now())
# Out:
# 200
#   Color Animal Alive
# 0   Red  Panda    23
# 2026-03-04 10:50:16.174162
